# %% [markdown]
# <a href="https://colab.research.google.com/github/andreshserna/Practicas-Python/blob/main/Reto_Programacion_Metodos_numericos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os 
import time
from IPython import display
from xml.dom import minidom
import math  
from mpl_toolkits.mplot3d import Axes3D
from google.colab import drive

drive.mount('/content/drive')
rute ="/content/drive/My Drive/Datos_Reto2"
Lista_a = os.listdir(rute)
print(Lista_a)

while True:
    Numero_a=int(input("ingrese el numero del archico que desee:"))
    if Numero_a in range(len(Lista_a)):
        print("el archivo seleccionado es:",Lista_a[Numero_a])
        Nombre_a = Lista_a[Numero_a]
        break
    else:
        print("ingreso un numero que no pertenece, intentalo de nuevo")

data=open("/content/drive/My Drive/Datos_Reto2" + "/" + str(Nombre_a))
xmldoc = minidom.parse(data)
track = xmldoc.getElementsByTagName('trkpt')
elevation=xmldoc.getElementsByTagName('ele')
datetime=xmldoc.getElementsByTagName('time')
n_track=len(track)

#PARSING GPX ELEMENT
lon_list=[]
lat_list=[]
h_list=[]
time_list=[]
for s in range(n_track):
    lon,lat=track[s].attributes['lon'].value,track[s].attributes['lat'].value
    elev=elevation[s].firstChild.nodeValue
    lon_list.append(float(lon))
    lat_list.append(float(lat))
    h_list.append(float(elev))
    # PARSING TIME ELEMENT
    dt=datetime[s].firstChild.nodeValue
    time_split=dt.split('T')
    hms_split=time_split[1].split(':')
    time_hour=int(hms_split[0])
    time_minute=int(hms_split[1])
    time_second=int(hms_split[2].split('Z')[0])
    total_second=time_hour*3600+time_minute*60+time_second
    time_list.append(total_second)

print(lon_list)
print(lat_list)
print(h_list)
print(time_list)

import plotly.express as px
import plotly.express as px
column_names = ["a", "b", "c"]
df = pd.DataFrame(columns = column_names)
print(df)
fig = px.line_3d(df,lon_list,lat_list,h_list)
fig.show()

plt.plot(time_list,h_list,)
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Lunch_Ride_2020-08-03.gpx', 'Morning_Ride_2020-08-23Domingo.gpx', 'Morning_Ride_2020-08-26Miercoles.gpx', 'Palmas_MTB_2020-08-30Domingo.gpx', 'Morning_Ride_2020-09-03Jueves.gpx', 'Morning_Ride_2020-09-05Sabado.gpx', 'Morning_Ride_2020-09-06Domingo.gpx', 'Afternoon_Ride_2020-09-06Domingo.gpx', 'Morning_Ride_2020-09-09Miercoles.gpx', 'Morning_Ride_2020-09-13Sabado_alRetiro.gpx', 'Morning_Ride_2020-09-12Sabado_AMedellin.gpx', 'Afternoon_Ride_2020-09-13Domingo.gpx', 'Morning_Ride_2020-09-19Sabado.gpx', 'Morning_Ride_2020-09-20Domingo.gpx', 'Morning_Ride_2020-09-25Viernes.gpx', 'Morning_Ride_2020-09-26Sabado.gpx', 'Morning_Ride_AltoUnion_2020-09-27Domingo.gpx', 'Morning_Ride_LaCeja_2020-09-27Domingo.gpx', 'Afternoon_Ride_2020-09-29Martes.gpx', 'Palmas_2020-09-30Miercoles.gpx']
# ingrese el numero del archico que desee:3
# ...

# %%
()
